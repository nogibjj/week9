# %%
# %load lib.py
import matplotlib.pyplot as plt
import polars as pl

def printMedian(df, target):
    print("median of" + target + ": " + str(df[target].median()))

def printDescribe(df):
    print(df.describe())

def printDF(df):
    print(df)


def visualize(df, target):
    plt.figure(figsize=(10, 6))
    plt.hist(df[target], bins=10, edgecolor="k", alpha=0.7)
    title = "Distribution of " + target
    plt.title(title)
    plt.xlabel(target)
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.tight_layout()
    loca = target + "_distribution_polar.png"
    plt.savefig(loca)
    plt.show()

# %%
import matplotlib.pyplot as plt
import polars as pl
import lib

df = pl.read_csv("nba.csv")
lib.printDF(df)
lib.printDescribe(df)
lib.printMedian(df, "Age")
lib.printMedian(df, "Weight")
lib.printMedian(df, "Salary")
lib.visualize(df, "Age")
lib.visualize(df, "Weight")
lib.visualize(df, "Salary")
# Out:
# shape: (458, 9)
# ┌──────────────┬──────────────┬────────┬──────────┬───┬────────┬────────┬─────────────┬────────────┐
# │ Name         ┆ Team         ┆ Number ┆ Position ┆ … ┆ Height ┆ Weight ┆ College     ┆ Salary     │
# │ ---          ┆ ---          ┆ ---    ┆ ---      ┆   ┆ ---    ┆ ---    ┆ ---         ┆ ---        │
# │ str          ┆ str          ┆ f64    ┆ str      ┆   ┆ str    ┆ f64    ┆ str         ┆ f64        │
# ╞══════════════╪══════════════╪════════╪══════════╪═══╪════════╪════════╪═════════════╪════════════╡
# │ Avery        ┆ Boston       ┆ 0.0    ┆ PG       ┆ … ┆ 6-2    ┆ 180.0  ┆ Texas       ┆ 7.730337e6 │
# │ Bradley      ┆ Celtics      ┆        ┆          ┆   ┆        ┆        ┆             ┆            │
# │ Jae Crowder  ┆ Boston       ┆ 99.0   ┆ SF       ┆ … ┆ 6-6    ┆ 235.0  ┆ Marquette   ┆ 6.796117e6 │
# │              ┆ Celtics      ┆        ┆          ┆   ┆        ┆        ┆             ┆            │
# │ John Holland ┆ Boston       ┆ 30.0   ┆ SG       ┆ … ┆ 6-5    ┆ 205.0  ┆ Boston      ┆ null       │
# │              ┆ Celtics      ┆        ┆          ┆   ┆        ┆        ┆ University  ┆            │
# │ R.J. Hunter  ┆ Boston       ┆ 28.0   ┆ SG       ┆ … ┆ 6-5    ┆ 185.0  ┆ Georgia     ┆ 1.14864e6  │
# │              ┆ Celtics      ┆        ┆          ┆   ┆        ┆        ┆ State       ┆            │
# │ …            ┆ …            ┆ …      ┆ …        ┆ … ┆ …      ┆ …      ┆ …           ┆ …          │
# │ Raul Neto    ┆ Utah Jazz    ┆ 25.0   ┆ PG       ┆ … ┆ 6-1    ┆ 179.0  ┆ null        ┆ 900000.0   │
# │ Tibor Pleiss ┆ Utah Jazz    ┆ 21.0   ┆ C        ┆ … ┆ 7-3    ┆ 256.0  ┆ null        ┆ 2.9e6      │
# │ Jeff Withey  ┆ Utah Jazz    ┆ 24.0   ┆ C        ┆ … ┆ 7-0    ┆ 231.0  ┆ Kansas      ┆ 947276.0   │
# │ null         ┆ null         ┆ null   ┆ null     ┆ … ┆ null   ┆ null   ┆ null        ┆ null       │
# └──────────────┴──────────────┴────────┴──────────┴───┴────────┴────────┴─────────────┴────────────┘
# shape: (9, 10)
# ┌────────────┬────────────┬────────────┬───────────┬───┬────────┬────────────┬─────────┬───────────┐
# │ describe   ┆ Name       ┆ Team       ┆ Number    ┆ … ┆ Height ┆ Weight     ┆ College ┆ Salary    │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ ---    ┆ ---        ┆ ---     ┆ ---       │
# │ str        ┆ str        ┆ str        ┆ f64       ┆   ┆ str    ┆ f64        ┆ str     ┆ f64       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪════════╪════════════╪═════════╪═══════════╡
# │ count      ┆ 458        ┆ 458        ┆ 458.0     ┆ … ┆ 458    ┆ 458.0      ┆ 458     ┆ 458.0     │
# │ null_count ┆ 1          ┆ 1          ┆ 1.0       ┆ … ┆ 1      ┆ 1.0        ┆ 85      ┆ 12.0      │
# │ mean       ┆ null       ┆ null       ┆ 17.678337 ┆ … ┆ null   ┆ 221.522976 ┆ null    ┆ 4.8427e6  │
# │ std        ┆ null       ┆ null       ┆ 15.96609  ┆ … ┆ null   ┆ 26.368343  ┆ null    ┆ 5.2292e6  │
# │ min        ┆ Aaron      ┆ Atlanta    ┆ 0.0       ┆ … ┆ 5-11   ┆ 161.0      ┆ Alabama ┆ 30888.0   │
# │            ┆ Brooks     ┆ Hawks      ┆           ┆   ┆        ┆            ┆         ┆           │
# │ 25%        ┆ null       ┆ null       ┆ 5.0       ┆ … ┆ null   ┆ 200.0      ┆ null    ┆ 1.035e6   │
# │ 50%        ┆ null       ┆ null       ┆ 13.0      ┆ … ┆ null   ┆ 220.0      ┆ null    ┆ 2.84196e6 │
# │ 75%        ┆ null       ┆ null       ┆ 25.0      ┆ … ┆ null   ┆ 240.0      ┆ null    ┆ 6.5e6     │
# │ max        ┆ Zaza       ┆ Washington ┆ 99.0      ┆ … ┆ 7-3    ┆ 307.0      ┆ Xavier  ┆ 2.5e7     │
# │            ┆ Pachulia   ┆ Wizards    ┆           ┆   ┆        ┆            ┆         ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴────────┴────────────┴─────────┴───────────┘
# median ofAge: 26.0
# median ofWeight: 220.0
# median ofSalary: 2839073.0
